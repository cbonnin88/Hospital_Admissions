# %% [markdown]
# <a href="https://colab.research.google.com/github/cbonnin88/Hospital_Admissions/blob/main/data_cleaning_and_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import polars as pl
import plotly.express as px
import gdown as gd

# %%
# Loading raw data
url = 'https://drive.google.com/uc?id=1QNAup1SELVeOsXwOxlvpObIdw8n6vLNc'
gd.download(url,'raw_patients.csv',quiet=True)
# Out:
# 'raw_patients.csv'

# %%
df_patients = pl.read_csv('raw_patients.csv')

# %%
df_patients.head()
# Out:
# shape: (5, 5)
# ┌────────────┬─────┬────────┬───────────┬────────┐
# │ patient_id ┆ age ┆ gender ┆ dept_code ┆ is_cmu │
# │ ---        ┆ --- ┆ ---    ┆ ---       ┆ ---    │
# │ i64        ┆ i64 ┆ str    ┆ str       ┆ i64    │
# ╞════════════╪═════╪════════╪═══════════╪════════╡
# │ 1          ┆ 29  ┆ M      ┆ Paris     ┆ 1      │
# │ 2          ┆ 19  ┆ M      ┆ 75        ┆ 0      │
# │ 3          ┆ 94  ┆ M      ┆ Paris     ┆ 0      │
# │ 4          ┆ 93  ┆ F      ┆ 93        ┆ 0      │
# │ 5          ┆ 20  ┆ F      ┆ 75        ┆ 1      │
# └────────────┴─────┴────────┴───────────┴────────┘

# %% [markdown]
# # **Cleaning Patient Data**

# %%
# Deduplication Data
df_patients = df_patients.unique(subset=['patient_id'])

# %%
# Standardize French Department Codes
dept_mapping = {
    'Paris': '75',
    '75001': '75',
    'Nanterre': '92'
}

# %%
df_patients = df_patients.with_columns(
    pl.col('dept_code').replace(dept_mapping).alias('dept_code')
)

# %%
# Handle Missing Gender
df_patients = df_patients.with_columns(
    pl.col('gender').fill_null('U')
)

# %%
print(f'Cleaned Patients: {df_patients.shape}')
# Out:
# Cleaned Patients: (120000, 5)

# %% [markdown]
# # **Cleaning Hospital Stays**

# %%
url='https://drive.google.com/uc?id=1dfwroRTisLNZvvrFJSPxVTOf_wYHTGTT'
gd.download(url,'raw_hospital_stay.csv',quiet=True)

df_stays = pl.read_csv('raw_hospital_stay.csv')

# %%
df_stays.head()
# Out:
# shape: (5, 7)
# ┌─────────┬────────────┬─────────────┬────────────────┬────────────────┬───────────┬───────────────┐
# │ stay_id ┆ patient_id ┆ hospital_id ┆ admission_date ┆ diagnosis_code ┆ stay_cost ┆ discharge_dat │
# │ ---     ┆ ---        ┆ ---         ┆ ---            ┆ ---            ┆ ---       ┆ e             │
# │ i64     ┆ i64        ┆ i64         ┆ str            ┆ str            ┆ f64       ┆ ---           │
# │         ┆            ┆             ┆                ┆                ┆           ┆ str           │
# ╞═════════╪════════════╪═════════════╪════════════════╪════════════════╪═══════════╪═══════════════╡
# │ 1       ┆ 16840      ┆ 13          ┆ 2023-04-05T00: ┆ E11.9          ┆ 7021.22   ┆ 2023-04-15T00 │
# │         ┆            ┆             ┆ 00:00.000000   ┆                ┆           ┆ :00:00.000000 │
# │ 2       ┆ 16291      ┆ 33          ┆ 2023-04-24T00: ┆ J45.9          ┆ 7420.92   ┆ 2023-05-04T00 │
# │         ┆            ┆             ┆ 00:00.000000   ┆                ┆           ┆ :00:00.000000 │
# │ 3       ┆ 71675      ┆ 48          ┆ 2023-12-09T00: ┆ J45.9          ┆ 13199.19  ┆ 2023-12-19T00 │
# │         ┆            ┆             ┆ 00:00.000000   ┆                ┆           ┆ :00:00.000000 │
# │ 4       ┆ 10568      ┆ 6           ┆ 2023-06-02T00: ┆ J45.9          ┆ 6828.89   ┆ 2023-06-12T00 │
# │         ┆            ┆             ┆ 00:00.000000   ┆                ┆           ┆ :00:00.000000 │
# │ 5       ┆ 25866      ┆ 14          ┆ 2023-06-03T00: ┆ E11.9          ┆ 3064.62   ┆ 2023-06-13T00 │
# │         ┆            ┆             ┆ 00:00.000000   ┆                ┆           ┆ :00:00.000000 │
# └─────────┴────────────┴─────────────┴────────────────┴────────────────┴───────────┴───────────────┘

# %%
# Converting Strings to Dates
df_stays = df_stays.with_columns([
    pl.col("admission_date").str.slice(0, 10).str.to_date("%Y-%m-%d"),
    pl.col("discharge_date").str.slice(0, 10).str.to_date("%Y-%m-%d")
])

# %%
# Addings a Length of Stay column
df_stays = df_stays.with_columns(
    (pl.col('discharge_date') - pl.col('admission_date')).dt.total_days().alias('los_days')
)

# %%
# Filter out any data errors (Discharge before Admission)
df_stays = df_stays.filter(pl.col("los_days") >= 0)

# %%
df_stays.head()
# Out:
# shape: (5, 8)
# ┌─────────┬────────────┬─────────────┬────────────┬────────────┬───────────┬────────────┬──────────┐
# │ stay_id ┆ patient_id ┆ hospital_id ┆ admission_ ┆ diagnosis_ ┆ stay_cost ┆ discharge_ ┆ los_days │
# │ ---     ┆ ---        ┆ ---         ┆ date       ┆ code       ┆ ---       ┆ date       ┆ ---      │
# │ i64     ┆ i64        ┆ i64         ┆ ---        ┆ ---        ┆ f64       ┆ ---        ┆ i64      │
# │         ┆            ┆             ┆ date       ┆ str        ┆           ┆ date       ┆          │
# ╞═════════╪════════════╪═════════════╪════════════╪════════════╪═══════════╪════════════╪══════════╡
# │ 1       ┆ 16840      ┆ 13          ┆ 2023-04-05 ┆ E11.9      ┆ 7021.22   ┆ 2023-04-15 ┆ 10       │
# │ 2       ┆ 16291      ┆ 33          ┆ 2023-04-24 ┆ J45.9      ┆ 7420.92   ┆ 2023-05-04 ┆ 10       │
# │ 3       ┆ 71675      ┆ 48          ┆ 2023-12-09 ┆ J45.9      ┆ 13199.19  ┆ 2023-12-19 ┆ 10       │
# │ 4       ┆ 10568      ┆ 6           ┆ 2023-06-02 ┆ J45.9      ┆ 6828.89   ┆ 2023-06-12 ┆ 10       │
# │ 5       ┆ 25866      ┆ 14          ┆ 2023-06-03 ┆ E11.9      ┆ 3064.62   ┆ 2023-06-13 ┆ 10       │
# └─────────┴────────────┴─────────────┴────────────┴────────────┴───────────┴────────────┴──────────┘

# %% [markdown]
# # **Export for BigQuery**

# %%
df_patients.write_csv('clean_patients.csv')
df_stays.write_csv('clean_hospital_stays.csv')
# Export the others as well
pl.read_csv('raw_hospitals.csv').write_csv('clean_hospitals.csv')
pl.read_csv('raw_pharmacy_claims.csv').write_csv('clean_pharmacy_claims.csv')

# %% [markdown]
# # **Readmission Frequency Analysis**

# %%
readmission_freq = (
    df_stays
    .group_by('patient_id')
    .agg(pl.count('stay_id').alias('stay_count'))
    .group_by('stay_count')
    .agg(pl.count('patient_id').alias('number_of_patients'))
    .sort('stay_count')
)

display(readmission_freq)
# Out:
# shape: (7, 2)
# ┌────────────┬────────────────────┐
# │ stay_count ┆ number_of_patients │
# │ ---        ┆ ---                │
# │ u32        ┆ u32                │
# ╞════════════╪════════════════════╡
# │ 1          ┆ 44084              │
# │ 2          ┆ 21896              │
# │ 3          ┆ 7476               │
# │ 4          ┆ 1863               │
# │ 5          ┆ 353                │
# │ 6          ┆ 67                 │
# │ 7          ┆ 11                 │
# └────────────┴────────────────────┘

# %%
fig_readmission = px.bar(
    readmission_freq.to_pandas(), # Plotly works better with pandas
    x='stay_count',
    y='number_of_patients',
    title='Frequency of Patient Hospitalizations',
    labels={'stay_count':'Number of Stays','number_of_patients':'Number of Patients'},
    text_auto=True,
    color_discrete_sequence=['#3498db']
)

fig_readmission.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="2b1c269c-4c1c-4947-a02f-65fd833bd924" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2b1c269c-4c1c-4947-a02f-65fd833bd924")) {                    Plotly.newPlot(                        "2b1c269c-4c1c-4947-a02f-65fd833bd924",                        [{"alignmentgroup":"True","hovertemplate":"Number of Stays=%{x}\u003cbr\u003eNumber of Patients=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#3498db","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","texttemplate":"%{y}","x":[1,2,3,4,5,6,7],"xaxis":"x","y":[44084,21896,7476,1863,353,67,11],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker ...

# %% [markdown]
# # **Average Cost by Age Group **

# %%
# Aggregate average Cost
age_analysis = (
    df_stays.join(df_patients, on='patient_id')
    .with_columns(
        pl.when(pl.col('age') < 30).then(pl.lit('18-29'))
        .when(pl.col('age') < 45).then(pl.lit('30-44'))
        .when(pl.col('age') < 65).then(pl.lit('45-64'))
        .otherwise(pl.lit('65+'))
        .alias('age_group')
    )
    .group_by('age_group')
    .agg(pl.col('stay_cost').mean().round(2).alias('avg_stay_cost'))
    .sort('age_group')
)

display(age_analysis)
# Out:
# shape: (4, 2)
# ┌───────────┬───────────────┐
# │ age_group ┆ avg_stay_cost │
# │ ---       ┆ ---           │
# │ str       ┆ f64           │
# ╞═══════════╪═══════════════╡
# │ 18-29     ┆ 7770.08       │
# │ 30-44     ┆ 7732.25       │
# │ 45-64     ┆ 7755.64       │
# │ 65+       ┆ 7758.43       │
# └───────────┴───────────────┘

# %%
fig_age_cost = px.pie(
    age_analysis.to_pandas(),
    values='avg_stay_cost',
    names='age_group',
    title='Proportion of Average Stay Cost by Age Group',
    hole=0.4,
    color_discrete_sequence=px.colors.sequential.RdBu
)

fig_age_cost.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="2a192300-2cc4-4f80-b0be-f3ddfaaeb7d1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2a192300-2cc4-4f80-b0be-f3ddfaaeb7d1")) {                    Plotly.newPlot(                        "2a192300-2cc4-4f80-b0be-f3ddfaaeb7d1",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hole":0.4,"hovertemplate":"age_group=%{label}\u003cbr\u003eavg_stay_cost=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["18-29","30-44","45-64","65+"],"legendgroup":"","name":"","showlegend":true,"values":[7770.08,7732.25,7755.64,7758.43],"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar": ...

# %% [markdown]
# # **Total Healthcare Expenditure by Department**

# %%
# Aggregation: Join and sum costs by dept_code
dept_analysis = (
    df_stays.join(df_patients, on='patient_id')
    .group_by('dept_code')
    .agg(pl.col('stay_cost').sum().alias('total_spend_euro'))
    .sort('total_spend_euro',descending=True)
)

display(dept_analysis)
# Out:
# shape: (4, 2)
# ┌───────────┬──────────────────┐
# │ dept_code ┆ total_spend_euro │
# │ ---       ┆ ---              │
# │ str       ┆ f64              │
# ╞═══════════╪══════════════════╡
# │ 75        ┆ 3.9806e8         │
# │ 92        ┆ 2.6664e8         │
# │ 94        ┆ 1.3311e8         │
# │ 93        ┆ 1.3273e8         │
# └───────────┴──────────────────┘

# %%
fig_dept = px.bar(
    dept_analysis.to_pandas(),
    x='dept_code',
    y='total_spend_euro',
    title='Total Healthcare Spend by French Department Code',
    labels={'dept_code':'Department','total_spend_euro':'Total Spend (€)'},
    color='total_spend_euro',
    color_continuous_scale='Viridis'
)

fig_dept.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="2dc77640-37f5-4671-b957-bfc7e5f6ce18" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2dc77640-37f5-4671-b957-bfc7e5f6ce18")) {                    Plotly.newPlot(                        "2dc77640-37f5-4671-b957-bfc7e5f6ce18",                        [{"alignmentgroup":"True","hovertemplate":"Department=%{x}\u003cbr\u003eTotal Spend (€)=%{marker.color}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":[398055837.6300008,266635168.28999972,133106597.02000022,132730456.72],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["75","92","94","93"],"xaxis":"x","y":[398055837.6300008,266635168.28999972,133106597.02000022,132730456.72],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"patter ...

# %% [markdown]
# # **Patient Age Distribution**

# %%
fig_age = px.histogram(
    df_patients.to_pandas(),
    x='age',
    nbins=20,
    title='Age Distribution of Patients (France ARS)',
    color_discrete_sequence=['#2ecc71'],
    labels={'count':'Number of Patients','age':'Age'}
)

fig_age.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="21d9c082-103b-4b25-8a62-199853aa29e4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("21d9c082-103b-4b25-8a62-199853aa29e4")) {                    Plotly.newPlot(                        "21d9c082-103b-4b25-8a62-199853aa29e4",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Age=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#2ecc71","pattern":{"shape":""}},"name":"","nbinsx":20,"offsetgroup":"","orientation":"v","showlegend":false,"x":[30,52,63,41,78,73,67,64,47,26,79,48,92,47,84,44,73,48,80,48,36,63,49,68,36,66,43,84,24,33,23,76,86,55,28,94,86,80,52,82,47,40,64,35,44,71,63,31,23,86,37,78,36,82,50,35,72,91,70,52,23,24,30,50,89,87,72,18,29,18,19,43,79,89,86,66,32,70,47,27,76,47,24,80,75,65,47,42,78,42,19,84,20,40,30,46,63,69,85,76,53,45,29,89,25,67,22,30,18,42,43,19,20,20,31,41,32,77,88,38,53,46,59,28,55,29,67,84,63,32,28,72,26,39,89,70,33,55,91,82,55,25,39,57,93,81,43,51,92,56,88,21,90,89,80,86,59,25,80,89,89,73,79,94,20,27,88,75,48,39,84,54,37,53,80,19,18,39,55,93,82,23,49,22,71,44,79,70,29,50,74,70,84,84,43,94,35,86,62,42,52,39,35,44,21,31,62,60,70,47,42,44,25,90,45,42,53,58,61,27,87,34,80,38,64,25,57,20,33,45,22,55,62,52,90,47,28,74,32,34,25,90,42,82,63,24,28,73,54,44,76,55,25,42,91,31,81,19,57,60,50,77,74,69,57,52,50,34,29,69,63,68,26,71,93,76,94,55,70,36,91,22,84,77,39,85,47,50,90,41,27,29,67,35,21,83,59,55,65,78,38,24,88,43,86,83,73,62,28,69,31,78,58,94,34,76,92,69,79,65,65,47,56,37,52,29,56,27,25,35,27,86,72,94,78,70,46,85,60,73,78,20,92,64,75,66,66,60,36,30,94,24,88,25,78,45,45,44,79,48,37,57,24,89,60,57,69,21,50,70,32,19,86,69,84,86,85,83,77,41,65,88,42,39,30,40,23,55,50,57,82,92,91,29,91,31,25,27,60,24,82,35,54,72,59,58,75,43,50,65,29,23,29,85,73,36,32,53,67,60,81,40,69,23,89,29,27,61,66,23,44,21,35,83,23,19,18,59,50,38,31,66,65,94,28,37,36,75,25,89,41,34,84,80,57,38,18,92,70,56,85,92,39,26,38,90,91,87,55,41,21,76,75,63,65,71,65,56,39,40,44,31,27,68,20,42,49,74,60,37,51,68,38,63,60,92,59,81,25,30,41,35,45,19,59,89,36,71,68,85,42,73,57,79,51,49,72,85,92,23,93,52,52,54,53,59,61,53,91,25,85,73,82,50,89,65,93,66,74,52,32,31,32,19,78,78,85,56,83,79,31,43,61,61,67,56,37,54,27,19,44,61,50,49,79,19,37,50,18,33,91,34,29,88,33,94,35,72,63,69,45,86,52,57,42,92,36,45,42,18,58,19,78,74,71,81,80,72,20,65,20,26,51,35,45,73,39,81,36,84,47,42,70,26,67,39,56,29,78,23,66,36,66,83,86,79,75,30,72,44,27,60,75,34,82,18,79,21,68,79,90,73,72,57,49,45,46,61,18,23,46,70,68,55,23,45,31,29,24,71,78,28,90,43,35,47,82,41,28,71,55,46,34,35,35,83,71,79,35,23,65,70,91,21,59,61,24,72,30,75,44,29,53,58,23,23,50,55,56,64,55,73,53,74,38,67,21,58,26,51,61,21,79,89,47,54,43,73,33,63,88,76,35,31,46,76,18,31,37,69,77,34,83,78,32,76,83,67,35,67,44,66,58,64,48,48,37,58,18,77,64,86,47,93,58,90,56,18,39,30,22,85,60,38,24,23,66,84,39,58,62,47,38,30,45,80,77,80,20,79,33,31,30,78,39,92,64,65,79,45,26,88,59,54,40,35,63,63,77,74,84,23,79,38,48,63,29,83,88,47,35,91,21,86,55,54,66,89,84,56,60,47,30,84,85,86,47,54,49,24,56,77,91,67,83,18,74,56,34,66,51,47,21,70,35,70,60,84,61,19,38,59,71,39,88,75,81,31,56,93,18,41,44,77,76,78,52,27,61,30,47,31,42,28,20,25,76,65,52,50,83,57,48,79,63,70,81,77,61,87,61,74,43,19,54,52,71,62,26,76,50,82,29,20,51,89,78,79,91,25,23,37,25,63,42,26,36,54,69,32,28,37,51,79,30,85,61,70,64,77,91,33,67,68,47,40,38,33,20,72,25,32,61,61,44,39,62,54,82,32,73,40,47,42,62,45,64,55,88,61,89,44,72,81,73,65,70,92,69,56,78,56,61,38,38,86,82,22,37,83,40,30,75,83,40,43,92,42,91,73,57,73,36,62,33,57,20,22,73,94,77,50,33,36,84,41,30,39,25,54,29,70,58,28,37,38,83,94,60,61,27,78,60,53,93,82,30,94,54,43,92,77,81,18,65,27,72,94,74,51,84,40,22,40,72,70,57,84,31,40,30,80 ...

# %% [markdown]
# # **Cost by Diagnosis (CIM-10)**

# %%
cost_summary = df_stays.group_by('diagnosis_code').agg(pl.col('stay_cost').mean().round(2).alias('avg_cost'))

display(cost_summary)
# Out:
# shape: (4, 2)
# ┌────────────────┬──────────┐
# │ diagnosis_code ┆ avg_cost │
# │ ---            ┆ ---      │
# │ str            ┆ f64      │
# ╞════════════════╪══════════╡
# │ J44.0          ┆ 7730.85  │
# │ E11.9          ┆ 7753.66  │
# │ J45.9          ┆ 7780.24  │
# │ I10            ┆ 7752.85  │
# └────────────────┴──────────┘

# %%
fig_cost = px.bar(
    cost_summary.to_pandas(),
    x='diagnosis_code',
    y='avg_cost',
    title='Average Stay Cost by CIM-10 Diagnosis Code',
    labels={'diagnosis_code':'Diagnosis','avg_cost':'Avg Cost (€)'},
    color='avg_cost',
    color_continuous_scale='Viridis'
)

fig_cost.update_layout(coloraxis_showscale=False)
fig_cost.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="ee062c63-6505-4c54-aeb8-eed1cf39446d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ee062c63-6505-4c54-aeb8-eed1cf39446d")) {                    Plotly.newPlot(                        "ee062c63-6505-4c54-aeb8-eed1cf39446d",                        [{"alignmentgroup":"True","hovertemplate":"Diagnosis=%{x}\u003cbr\u003eAvg Cost (€)=%{marker.color}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":[7730.85,7753.66,7780.24,7752.85],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["J44.0","E11.9","J45.9","I10"],"xaxis":"x","y":[7730.85,7753.66,7780.24,7752.85],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}]," ...
